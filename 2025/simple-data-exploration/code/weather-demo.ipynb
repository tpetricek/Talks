# %%
#r "nuget:FSharp.Data"
#r "nuget: Plotly.NET, 4.0.0"
#r "nuget: Plotly.NET.Interactive, 4.0.0"
open FSharp.Data
open Plotly.NET
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Data, 6.6.0</span></li><li><span>Plotly.NET, 4.0.0</span></li><li><span>Plotly.NET.Interactive, 4.0.0</span></li></ul></div></div>

# %%
type W = JsonProvider<"http://api.openweathermap.org/data/2.5/forecast/daily?q=Prague&mode=json&units=metric&cnt=10&APPID=cb63a1cf33894de710a1e3a64f036a27">
let w = W.GetSample()

[ for d in w.List -> d.Temp.Day ]
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 10.21, 11.35, 10.42, 9.16, 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>10.21</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 11.35, 10.42, 9.16, 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>11.35</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 10.42, 9.16, 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>10.42</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 9.16, 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>9.16</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>9.62</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td>7.82</td></tr><tr><td>TailOrNull</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td>Head</td><td>7.82</td></tr><tr><td>Tail</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Head</td><td><div class="dni-plaintext"><pre>9.62</pre></div></td></tr><tr><td>Tail</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td>7.82</td></tr><tr><td>TailOrNull</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td>Head</td><td>7.82</td></tr><tr><td>Tail</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Head</td><td><div class="dni-plaintext"><pre>9.16</pre></div></td></tr><tr><td>Tail</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 9.62, 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>9.62</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td>7.82</td></tr><tr><td>TailOrNull</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td>Head</td><td>7.82</td></tr><tr><td>Tail</td><td>[ 7.66, 8.11, 7.42, 8.32 ]</td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ 7.82, 7.66, 8.11, 7.42, 8.32 ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Head</td><td><div class="dni-plaintext"><pre>9.62</pre></div></td></tr><tr><td>Tail</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 7.82, 7.66, 8.11, 7.42, 8.3 ...
